# %%
import pandas as pd
import seaborn as sns

# %%
in_loop_data = pd.read_csv("../data/inloop_labeled.csv")
in_loop_data['lt'] = (in_loop_data['lt'])*10**-9

# %%
in_loop_data['lt'].describe()
# Out:
# count    4052.000000
# mean        0.763766
# std         1.008770
# min         0.000000
# 25%         0.098842
# 50%         0.498182
# 75%         0.957830
# max         9.435461
# Name: lt, dtype: float64

# %%
sns.histplot(in_loop_data['lt'], kde=True)
# Out:
# <AxesSubplot:xlabel='lt', ylabel='Count'>

# %%
in_loop_data[(in_loop_data['lt'] < 8) & (in_loop_data['spd'] > 0)].to_csv('../data/inloop_labeled.csv')

# %%
sns.histplot(in_loop_data[(in_loop_data['lt'] < 8) & (in_loop_data['spd'] > 0)]['lt'], kde=True)
# Out:
# <AxesSubplot:xlabel='lt', ylabel='Count'>
